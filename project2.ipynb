# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
import numpy as np

# %%
# length , width , type
data = [[3, 1.5 ,1] ,
        [2 ,1 , 0],
       [4,1.5,1],
       [3,1,0],
       [3.5, 0.5 , 1],
       [2, 0.5 , 0],
       [5 ,1 , 1],
        [1,1,0]]
unknown = [4.5 , 1]

# %%
data[7]
# Out:
# [1, 1, 0]

# %%
w1 = np.random.randn()
w2 = np.random.randn()
b = np.random.randn()

# %%
w1
# Out:
# -0.9111480471681617

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
t = np.linspace(-6,6,10)

# %%
t
# Out:
# array([-6.        , -4.66666667, -3.33333333, -2.        , -0.66666667,
#         0.66666667,  2.        ,  3.33333333,  4.66666667,  6.        ])

# %%
s = sigmoid(t)

# %%
plt.plot(t, s)

# %%
plt

# %%
plt.axis([0,6,0,6])
plt.grid()
for i in range(len(data)):
    point = data[i]
    color = "r"
    if point[2] == 0:
        color = "b"
    plt.scatter(point[0] , point[1] , c = color)

# %%
for i in range(1000):
 
    rd = np.random.randint(len(data))
    point = data[rd]
    print(point)
# Out:
# [5, 1, 1]
# [4, 1.5, 1]
# [2, 1, 0]
# [4, 1.5, 1]
# [1, 1, 0]
# [3.5, 0.5, 1]
# [2, 1, 0]
# [2, 1, 0]
# [5, 1, 1]
# [3.5, 0.5, 1]
# [1, 1, 0]
# [1, 1, 0]
# [2, 0.5, 0]
# [3.5, 0.5, 1]
# [1, 1, 0]
# [1, 1, 0]
# [4, 1.5, 1]
# [1, 1, 0]
# [1, 1, 0]
# [2, 1, 0]
# [4, 1.5, 1]
# [3.5, 0.5, 1]
# [3.5, 0.5, 1]
# [3, 1.5, 1]
# [3.5, 0.5, 1]
# [3.5, 0.5, 1]
# [4, 1.5, 1]
# [3.5, 0.5, 1]
# [1, 1, 0]
# [4, 1.5, 1]
# [2, 0.5, 0]
# [2, 0.5, 0]
# [2, 1, 0]
# [1, 1, 0]
# [3, 1.5, 1]
# [5, 1, 1]
# [3.5, 0.5, 1]
# [2, 1, 0]
# [3, 1.5, 1]
# [4, 1.5, 1]
# [3, 1.5, 1]
# [5, 1, 1]
# [3, 1, 0]
# [2, 0.5, 0]
# [3, 1.5, 1]
# [4, 1.5, 1]
# [3.5, 0.5, 1]
# [2, 1, 0]
# [3, 1.5, 1]
# [5, 1, 1]
# [4, 1.5, 1]
# [3, 1, 0]
# [4, 1.5, 1]
# [1, 1, 0]
# [4, 1.5, 1]
# [5, 1, 1]
# [1, 1, 0]
# [2, 0.5, 0]
# [4, 1.5, 1]
# [2, 0.5, 0]
# [2, 0.5, 0]
# [1, 1, 0]
# [3, 1.5, 1]
# [3.5, 0.5, 1]
# [1, 1, 0]
# [3.5, 0.5, 1]
# [3.5, 0.5, 1]
# [2, 1, 0]
# [3, 1, 0]
# [1, 1, 0]
# [5, 1, 1]
# [2, 1, 0]
# [3, 1.5, 1]
# [2, 1, 0]
# ...
